# %%
import geopandas as gpd
# Out:
# /Users/joaopedro/env/lib/python3.8/site-packages/geopandas/_compat.py:123: UserWarning: The Shapely GEOS version (3.11.3-CAPI-1.17.3) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(
# /var/folders/fx/kx7__pwn2tv9449n14s5rx1w0000gn/T/ipykernel_18007/3841419929.py:1: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# ...

# %%
dtf = gpd.read_file("../../IBGE/base_grafica_20200519_110000/AGSN_2019/AGSN_2019.shp")
dtf

# %%
dtf.groupby('UF').sum('SUM_EDOC').sort_values('SUM_EDOC', ascending=False)
# Out:
#                      SUM_EDOC       UH_Dist  UH_NU_END      AP1_Dist  \
# UF
# São Paulo             1066423  5.909627e+06    3687732  2.139400e+06
# Rio de Janeiro         717296  3.445163e+06    1265864  1.412705e+06
# Bahia                  469647  9.197076e+05     217170  4.042893e+05
# Pará                   432518  1.536727e+06     366852  5.001477e+05
# Amazonas               393995  8.933649e+05     246161  4.584168e+05
# Pernambuco             327090  8.779175e+05     296219  2.842766e+05
# Espírito Santo         306199  1.842257e+06     210409  4.737887e+05
# Ceará                  243638  1.550565e+06     758038  6.304419e+05
# Minas Gerais           230995  1.512155e+06     712683  4.639449e+05
# Maranhão               144565  4.571301e+05      25638  2.361751e+05
# Paraná                 135128  2.729057e+06    1123749  8.046237e+05
# Rio Grande do Sul      131161  1.451776e+06     680021  4.095417e+05
# ...
